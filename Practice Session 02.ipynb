# %% [markdown]
# ##

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\amish\Desktop\My Jupyter Notebooks\Data Sets\Automobile_data.csv", index_col="index")
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %% [markdown]
# **Showing top and bottom 5 rows only**

# %%
df.head(5)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
df.tail(5)
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
# 87          volvo      sedan       104.3   188.8         ohc             four
# 88          volvo      wagon       104.3   188.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 81             85               27   7975.0
# 82             52               37   7995.0
# 86            100               26   9995.0
# 87            114               23  12940.0
# 88            114               23  13415.0

# %% [markdown]
# **Replacing na values with NaN**

# %%
df = pd.read_csv(r"C:\Users\amish\Desktop\My Jupyter Notebooks\Data Sets\Automobile_data.csv", index_col="index", na_values={
    'price':["?","n.a"],
    'stroke':["?","n.a"],
    'horsepower':["?","n.a"],
    'peak-rpm':["?","n.a"],
    'average-mileage':["?","n.a"]
})
df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %% [markdown]
# ## Using DataFrame.loc[]
#
# **Purpose: Access a group of rows and columns by label(s) or a boolean array.**
#
# ***.loc[] is primarily label based.***

# %%
df.loc[5:10] # numbers are treated as labels of index
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 5        audi      sedan        99.8   177.3         ohc             five
# 6        audi      wagon       105.8   192.7         ohc             five
# 9         bmw      sedan       101.2   176.8         ohc             four
# 10        bmw      sedan       101.2   176.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 5             110               19  15250.0
# 6             110               19  18920.0
# 9             101               23  16430.0
# 10            101               23  16925.0

# %%
gf = df.set_index("company")
gf
# Out:
#               body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero  convertible        88.6   168.8        dohc             four
# alfa-romero    hatchback        94.5   171.2        ohcv              six
# audi               sedan        99.8   176.6         ohc             four
# audi               sedan        99.4   176.6         ohc             five
# ...                  ...         ...     ...         ...              ...
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volkswagen         sedan        97.3   171.7         ohc             four
# volvo              sedan       104.3   188.8         ohc             four
# volvo              wagon       104.3   188.8         ohc             four
#
#              horsepower  average-mileage    price
# company
# ...

# %%
gf.loc["audi"] #accessing all the label specific rows
# Out:
#         body-style  wheel-base  length engine-type num-of-cylinders  \
# company
# audi         sedan        99.8   176.6         ohc             four
# audi         sedan        99.4   176.6         ohc             five
# audi         sedan        99.8   177.3         ohc             five
# audi         wagon       105.8   192.7         ohc             five
#
#          horsepower  average-mileage    price
# company
# audi            102               24  13950.0
# audi            115               18  17450.0
# audi            110               19  15250.0
# audi            110               19  18920.0

# %%
gf.loc["audi","price"] # accessing rows and column specific values
# Out:
# company
# audi    13950.0
# audi    17450.0
# audi    15250.0
# audi    18920.0
# Name: price, dtype: float64

# %% [markdown]
# **Details of the most expensive car**

# %%
df.loc[df["price"] == df["price"].max()]   # details of car with the highest cost
# Out:
#              company body-style  wheel-base  length engine-type  \
# index
# 47     mercedes-benz    hardtop       112.0   199.2        ohcv
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 47               eight         184               14  45400.0

# %% [markdown]
# **Printing details of all the Toyota cars -** *using .loc[ ] and groupby()*

# %%
df.loc[df["company"]=="toyota"] #using .loc[]
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66             62               35   5348.0
# 67             62               31   6338.0
# 68             62               31   6488.0
# 69             62               31   6918.0
# 70             62               27   7898.0
# 71             62               27   8778.0
# 79            156               19  15750.0

# %%
manufacturer = df.groupby("company") # By creating a groupby() object
manufacturer.get_group("toyota")
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 66     toyota  hatchback        95.7   158.7         ohc             four
# 67     toyota  hatchback        95.7   158.7         ohc             four
# 68     toyota  hatchback        95.7   158.7         ohc             four
# 69     toyota      wagon        95.7   169.7         ohc             four
# 70     toyota      wagon        95.7   169.7         ohc             four
# 71     toyota      wagon        95.7   169.7         ohc             four
# 79     toyota      wagon       104.5   187.8        dohc              six
#
#        horsepower  average-mileage    price
# index
# 66             62               35   5348.0
# 67             62               31   6338.0
# 68             62               31   6488.0
# 69             62               31   6918.0
# 70             62               27   7898.0
# 71             62               27   8778.0
# 79            156               19  15750.0

# %% [markdown]
# ## value_counts()
#
# **Counting the number of cars per company**
#
# Series.value_counts(self, normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# Return a Series containing counts of unique values.

# %%
df["company"].value_counts(ascending = True)
# Out:
# volvo            2
# dodge            2
# isuzu            3
# alfa-romero      3
# honda            3
# jaguar           3
# porsche          3
# chevrolet        3
# mercedes-benz    4
# volkswagen       4
# mitsubishi       4
# audi             4
# mazda            5
# nissan           5
# bmw              6
# toyota           7
# Name: company, dtype: int64

# %%
manufacturer = df.groupby("company")
manufacturer["price"].max()
# Out:
# company
# alfa-romero      16500.0
# audi             18920.0
# bmw              41315.0
# chevrolet         6575.0
# dodge             6377.0
# honda            12945.0
# isuzu             6785.0
# jaguar           36000.0
# mazda            18344.0
# mercedes-benz    45400.0
# mitsubishi        8189.0
# nissan           13499.0
# porsche          37028.0
# toyota           15750.0
# volkswagen        9995.0
# volvo            13415.0
# Name: price, dtype: float64

# %% [markdown]
# ## sort_values()
#
# **DataFrame.sort_values(self, by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')**

# %%
df.sort_values(by=["price"],ascending=False)
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 47     mercedes-benz      hardtop       112.0   199.2        ohcv
# 14               bmw        sedan       103.5   193.8         ohc
# 46     mercedes-benz        sedan       120.9   208.1        ohcv
# 62           porsche  convertible        89.5   168.9        ohcf
# 15               bmw        sedan       110.0   197.0         ohc
# ...              ...          ...         ...     ...         ...
# 36             mazda    hatchback        93.1   159.1         ohc
# 16         chevrolet    hatchback        88.4   141.1           l
# 31             isuzu        sedan        94.5   155.9         ohc
# 32             isuzu        sedan        94.5   155.9         ohc
# 63           porsche    hatchback        98.4   175.7       dohcv
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 47               eight         184               14  45400.0
# ...

# %% [markdown]
# ## concat()
#
# *pandas.concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False, keys=None, levels=None, names=None, verify_integrity=False, sort=None, copy=True)*

# %%
GermanCars = pd.DataFrame({
    'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 
    'Price': [23845, 171995, 135925 , 71400]
})
JapaneseCars = pd.DataFrame({
    'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '],
    'Price': [29995, 23600, 61500 , 58900]
})

pd.concat([GermanCars,JapaneseCars],keys=["German","Japanese"])
# Out:
#                 Company   Price
# German   0         Ford   23845
#          1     Mercedes  171995
#          2          BMV  135925
#          3         Audi   71400
# Japanese 0       Toyota   29995
#          1        Honda   23600
#          2       Nissan   61500
#          3  Mitsubishi    58900

# %%
car_price = { "Company": ['Toyota', 'Honda', 'BMV', 'Audi'], 
    'Price': [23845, 17995, 135925 , 71400]}
car_horsePower = {'Company': ['Toyota', 'Honda', 'BMV', 'Audi'], 
                  'horsepower': [141, 80, 182 , 160]}
car_price_df = pd.DataFrame.from_dict(car_price)
car_horsePower_df = pd.DataFrame.from_dict(car_horsePower)

# %%
car_price_df
# Out:
#   Company   Price
# 0  Toyota   23845
# 1   Honda   17995
# 2     BMV  135925
# 3    Audi   71400

# %%
car_horsePower_df
# Out:
#   Company  horsepower
# 0  Toyota         141
# 1   Honda          80
# 2     BMV         182
# 3    Audi         160

# %% [markdown]
# ## Merging the two dataframes

# %%
pd.merge(car_price_df, car_horsePower_df, on = "Company")
# Out:
#   Company   Price  horsepower
# 0  Toyota   23845         141
# 1   Honda   17995          80
# 2     BMV  135925         182
# 3    Audi   71400         160
